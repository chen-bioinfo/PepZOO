# %%
 # -*- coding: utf-8 -*-
import numpy as np
import matplotlib.pyplot as plt
params = {
    'axes.labelsize': 56,
    'axes.titlesize':56,
    'font.size': 56, 
    'legend.fontsize': 56,
    'xtick.labelsize': 56, 
    'ytick.labelsize': 56,
}
plt.rcParams.update(params)
# read the generated peptides
with open('../result_4_binding_toxic.txt', 'r') as rf:
    data = rf.readlines()
j = 0
x = np.linspace(start = 0,stop = 20, num=21)
y = []
z = []
while j < 25:
    i = 1
    k = 1
    y1 = []
    y2 = []
    while i <= (1108 - 27):
        row = data[i+2+j:i+3+j][0].split('\t')
        y1.append(row[2])
        y2.append(row[3].split('\n')[0])
        i = i + 27
    y1 = list(map(float, y1))
    y2 = list(map(float, y2))
    fig = plt.figure(figsize=(24,28),dpi=300)
    ax = fig.add_subplot(111)
    ax.plot(x,y1[:21], '-', label = 'binding score', color='blue')
    ax.yaxis.set_major_formatter('{:.2f}'.format)
    ax.set_xticks([0,1,5,10,15,20])
    ax.set_xticklabels(['0','1','5','10','15','20'])
    ax2 = ax.twinx()
    ax2.plot(x,y2[:21], '-r', label = 'toxic score', color='red')
    fig.legend(loc=4, bbox_to_anchor=(1,1), bbox_transform=ax.transAxes)
    # ax.set_xlabel("iteration")
    # ax.set_ylabel(r"binding score")
    # ax2.set_ylabel(r"toxic score")
    plt.savefig(f'figure/binding_toxic/figure{j+1}.pdf')
    # plt.show()
    plt.close()
    j = j + 1

# %%
 # -*- coding: utf-8 -*-
import numpy as np
import matplotlib.pyplot as plt
params = {
    'axes.labelsize': 56,
    'axes.titlesize':56,
    'font.size': 56, 
    'legend.fontsize': 56,
    'xtick.labelsize': 56, 
    'ytick.labelsize': 56,
}
plt.rcParams.update(params)
with open('../result_toxic.txt', 'r') as rf:
    data = rf.readlines()
j = 0
x = np.linspace(start = 0,stop = 20, num=21)
y = []
z = []
while j < 25:
    i = 1
    k = 1
    y1 = []
    y2 = []
    while i <= (1108 - 27):
        row = data[i+2+j:i+3+j][0].split('\t')
        y1.append(row[2])
        y2.append(row[3].split('\n')[0])
        i = i + 27
    y1 = list(map(float, y1))
    y2 = list(map(float, y2))
    fig = plt.figure(figsize=(18,12),dpi=300)
    ax = fig.add_subplot(111)
    ax.plot(x,y2[:21], '-', label = 'binding score', color='blue')
    ax.yaxis.set_major_formatter('{:.2f}'.format)
    ax2 = ax.twinx()
    ax2.plot(x,y1[:21], '-r', label = 'toxic score', color='red')
    # fig.legend(loc=4, bbox_to_anchor=(1,1), bbox_transform=ax.transAxes)
    # ax.set_xlabel("iteration")
    # ax.set_ylabel(r"binding score")
    # ax2.set_ylabel(r"toxic score")
    ax.set_xticks([0,1,5,10,15,20])
    ax.set_xticklabels(['0','1','5','10','15','20'])
    plt.savefig(f'figure/toxicity/figure{j+1}.pdf')
    plt.close()
    j = j + 1

# %%
 # -*- coding: utf-8 -*-
import numpy as np
import matplotlib.pyplot as plt
params = {
    'axes.labelsize': 56,
    'axes.titlesize':56,
    'font.size': 56, 
    'legend.fontsize': 56,
    'xtick.labelsize': 56, 
    'ytick.labelsize': 56,
}
plt.rcParams.update(params)
with open('../result_binding.txt', 'r') as rf:
    data = rf.readlines()
j = 0
x = np.linspace(start = 0,stop = 20, num=21)
y = []
z = []
while j < 25:
    i = 1
    k = 1
    y1 = []
    y2 = []
    while i <= (1108 - 27):
        row = data[i+2+j:i+3+j][0].split('\t')
        y1.append(row[2])
        y2.append(row[3].split('\n')[0])
        i = i + 27
    y1 = list(map(float, y1))
    y2 = list(map(float, y2))
    fig = plt.figure(figsize=(18,12),dpi=300)
    ax = fig.add_subplot(111)
    ax.plot(x,y1[:21], '-', label = 'binding score', color='blue')
    ax.yaxis.set_major_formatter('{:.2f}'.format)
    ax2 = ax.twinx()
    ax2.plot(x,y2[:21], '-r', label = 'toxic score', color='red')
    # fig.legend(loc=4, bbox_to_anchor=(1,1), bbox_transform=ax.transAxes)
    # ax.set_xlabel("iteration")
    # ax.set_ylabel(r"binding score")
    # ax2.set_ylabel(r"toxic score")
    ax.set_xticks([0,1,5,10,15,20])
    ax.set_xticklabels(['0','1','5','10','15','20'])
    plt.savefig(f'figure/binding/figure{j+1}.pdf')
    plt.close()
    j = j + 1
